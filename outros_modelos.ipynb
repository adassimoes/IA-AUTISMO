# %% [markdown]
# # Modelo Inicial

# %%
import pandas as pd
from adr import dataset,metrics # dataset e metricas
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import tree 
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold 
from sklearn.metrics import confusion_matrix 
from sklearn.utils.multiclass import unique_labels
import sklearn.metrics
from sklearn import tree
from pprint import pprint

# %matplotlib inline

# %%
# Criando dataframe
df = dataset.autism()
#df.set_index('id', inplace=True)
df.head()
# Out:
#    id  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0   1         1         1         1         1         0         0         1
# 1   2         1         1         0         1         0         0         0
# 2   3         1         1         0         1         1         0         1
# 3   4         1         1         0         1         0         0         1
# 4   5         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0  ...       f  White-European      no     no
# 1         1         0  ...       m          Latino      no    yes
# 2         1         1  ...       m          Latino     yes    yes
# 3         1         0  ...       f  White-European      no    yes
# 4         1         0  ...       f               ?      no     no
#
#    contry_of_res used_app_before result     age_desc  relation Class/ASD
# 0  United States              no      6  18 and more      Self        NO
# 1         Brazil              no      5  18 and more      Self        NO
# 2          Spain              no      8  18 and more    Parent       YES
# 3  United States              no      6  18 and more      Self        NO
# 4          Egypt              no      2  18 and more         ?        NO
#
# [5 rows x 22 columns]

# %%
# Função de plotagem da matriz de confusão
def plot_confusion_matrix(y_test,result,cmap = plt.cm.Blues):
    # Confusion matrix
    cm = confusion_matrix(y_test,result)
    classe = unique_labels(y_test,result)
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classe, yticklabels=classe,
           title= 'Matriz de confusão',
           ylabel='Rótulo real',
           xlabel='Rótulo previsto')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j]),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# ## Feature Engineering
# Nessa etapa será selecionado as features que vamos utilizar no modelo baseline.

# %%
# Selecionando colunas com os traços comportamentais.
columns = ['A{}_Score'.format(i) for i in range(1,11)]

columns
# Out:
# ['A1_Score',
#  'A2_Score',
#  'A3_Score',
#  'A4_Score',
#  'A5_Score',
#  'A6_Score',
#  'A7_Score',
#  'A8_Score',
#  'A9_Score',
#  'A10_Score']

# %%
# Separando em variáveis preditoras X e alvo da nossa predição Y
X = df[columns]
X
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score
# 0           1         0          0
# 1           1         0          1
# 2           1         1          1
# 3           1         0          1
# 4           1         0          0
# ..        ...       ...        ...
# 699         1         1          1
# 700         1         0          1
# 701         1         0          1
# 702         0         1          1
# 703         1         1          1
#
# [704 rows x 10 columns]

# %%
Y = df['Class/ASD']

# Para melhor entendimento do dataset, iremos renomear os valores de Y
Y = Y.replace({'NO':'Sem_Autismo','YES':'Autismo'})
Y
# Out:
# 0      Sem_Autismo
# 1      Sem_Autismo
# 2          Autismo
# 3      Sem_Autismo
# 4      Sem_Autismo
#           ...
# 699        Autismo
# 700    Sem_Autismo
# 701        Autismo
# 702    Sem_Autismo
# 703        Autismo
# Name: Class/ASD, Length: 704, dtype: object

# %% [markdown]
# ## Modeling e Analysis
# Nessa etapa aplicaremos o modelo que foi selecionado e com isso a contrução das predições do nosso modelo baseline.
#
# Modelo selecionado: Decision Tree
# Motivo: Fácil compreensão.

# %%
# Criação do modelo

baseline = tree.DecisionTreeClassifier(random_state=42)
baseline
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## Treino e Teste

# %%
# Separando em treino e teste
x_train,x_test,y_train,y_test = train_test_split(X,Y,
                                                 test_size = 0.4,
                                                 random_state = 40)

# Treinando o modelo
test1 = baseline.fit(x_train,y_train)

results = test1.predict(x_test)
y_pred = results
table = pd.DataFrame(list(zip(y_test, y_pred)), columns=['y_test', 'y_pred'])
table.head()
# Out:
#         y_test       y_pred
# 0  Sem_Autismo  Sem_Autismo
# 1      Autismo  Sem_Autismo
# 2      Autismo      Autismo
# 3      Autismo  Sem_Autismo
# 4  Sem_Autismo  Sem_Autismo

# %%
print('Exemplos de Falso Negativos')
table[(table.y_test == 'Autismo') & (table.y_pred == 'Sem_Autismo')]
# Out:
# Exemplos de Falso Negativos
#       y_test       y_pred
# 1    Autismo  Sem_Autismo
# 3    Autismo  Sem_Autismo
# 5    Autismo  Sem_Autismo
# 29   Autismo  Sem_Autismo
# 156  Autismo  Sem_Autismo
# 159  Autismo  Sem_Autismo
# 192  Autismo  Sem_Autismo
# 206  Autismo  Sem_Autismo
# 239  Autismo  Sem_Autismo

# %%
print('Exemplos de Falso Positivos')
table[(table.y_test == 'Sem_Autismo') & (table.y_pred == 'Autismo')]
# Out:
# Exemplos de Falso Positivos
#           y_test   y_pred
# 7    Sem_Autismo  Autismo
# 53   Sem_Autismo  Autismo
# 128  Sem_Autismo  Autismo
# 134  Sem_Autismo  Autismo
# 157  Sem_Autismo  Autismo
# 162  Sem_Autismo  Autismo
# 211  Sem_Autismo  Autismo
# 222  Sem_Autismo  Autismo

# %%
# Informações do modelo
plot_confusion_matrix(y_test,results)
metrics1 = metrics.classification_report(y_test, y_pred, ['Sem_Autismo', 'Autismo'])
plt.show()

# %%
#print("Métricas do modelo que implementamos: \n")
#pprint(metrics1)
#print()
print("Métricas do modelo implementado: \n")
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
# Métricas do modelo implementado:
#
#               precision    recall  f1-score   support
#
#      Autismo       0.90      0.89      0.90        83
#  Sem_Autismo       0.95      0.96      0.96       199
#
#     accuracy                           0.94       282
#    macro avg       0.93      0.93      0.93       282
# weighted avg       0.94      0.94      0.94       282

# %% [markdown]
# ##  K-Fold Cross Validation

# %%
# Validação cruzada k-fold
#kf  = KFold(n_splits = 5, shuffle = True, random_state = 1)
skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 1)
print(skf)
# Out:
# StratifiedKFold(n_splits=5, random_state=1, shuffle=True)

# %%
metricas = []
i = 0
# Separando as bases de treino e teste
for train,test in skf.split(X,Y):
    #print(train)
    #print(test)
    # Dicionaro de treino
    train_x, test_x = X.iloc[train], X.iloc[test]
    train_y, test_y = Y.iloc[train], Y.iloc[test]
    aux = baseline.fit(train_x,train_y)
    rst = aux.predict(test_x)
    metricas.append(metrics.classification_report(test_y, rst, ['Sem_Autismo', 'Autismo']))
    #print('Métricas {} \n  \n{}'.format(i, sklearn.metrics.classification_report(test_y, rst)))
    print('Métricas da iteração {}  \n{}\n'.format(i, metricas[i]))
    plot_confusion_matrix(test_y,rst)
    i+=1
# Out:
# Métricas da iteração 0
# {'accuracy': 2.1041666666666665, 'precision': 0.9603960396039604, 'recall': 0.941747572815534, 'f1': 0.9509803921568628}
#
# Métricas da iteração 1
# {'accuracy': 2.2045454545454546, 'precision': 1.0, 'recall': 0.941747572815534, 'f1': 0.97}
#
# Métricas da iteração 2
# {'accuracy': 2.282608695652174, 'precision': 0.9523809523809523, 'recall': 0.970873786407767, 'f1': 0.9615384615384616}
#
# Métricas da iteração 3
# {'accuracy': 2.1, 'precision': 0.9333333333333333, 'recall': 0.9514563106796117, 'f1': 0.9423076923076923}
#
# Métricas da iteração 4
# {'accuracy': 2.1555555555555554, 'precision': 0.9896907216494846, 'recall': 0.9320388349514563, 'f1': 0.9600000000000001}

# %%
# Calculo da Média e Desvio padrão das métricas
ac = np.array([metricas[x]['accuracy'] for x in range(5)])
pc = np.array([metricas[x]['precision'] for x in range(5)])
rc = np.array([metricas[x]['recall'] for x in range(5)])
f1 = np.array([metricas[x]['f1'] for x in range(5)])

# Média e devio padrão
me_ac = np.mean(ac)
std_ac = np.std(ac)

print('Accuracy - média: {} e desvio padrão:: {}'.format(me_ac,std_ac))

me_pc = np.mean(pc)
std_pc = np.std(pc)

print('Precision - média: {} e desvio padrão:: {}'.format(me_pc,std_pc))

me_rc = np.mean(rc)
std_rc = np.std(rc)

print('Recall - média: {} e desvio padrão:: {}'.format(me_rc,std_rc))

me_f1 = np.mean(f1)
std_f1 = np.std(f1)

print('F1 Score - média: {} e desvio padrão:: {}'.format(me_f1,std_f1))
# Out:
# Accuracy - média: 2.16937527448397 e desvio padrão:: 0.06828590646607911
# Precision - média: 0.9671602093935462 e desvio padrão:: 0.024472489878924756
# Recall - média: 0.9475728155339805 e desvio padrão:: 0.013169572782767505
# F1 Score - média: 0.9569653092006034 e desvio padrão:: 0.00949411607037626

# %% [markdown]
# ## Feature Importance

# %%
dic = {i:baseline.feature_importances_[v] for v,i in enumerate(X.columns)}
dic
# Out:
# {'A1_Score': 0.051508013364642495,
#  'A2_Score': 0.03253039010895425,
#  'A3_Score': 0.056255512600899775,
#  'A4_Score': 0.06302434114266214,
#  'A5_Score': 0.1194562881913718,
#  'A6_Score': 0.05892905622789979,
#  'A7_Score': 0.07900783392115956,
#  'A8_Score': 0.06219253182137766,
#  'A9_Score': 0.43261732154738064,
#  'A10_Score': 0.044478711073651866}

# %%
pd.DataFrame(list(dic.items()), columns=['feature', 'importance']).sort_values(by='importance', ascending=False)
# Out:
#      feature  importance
# 8   A9_Score    0.432617
# 4   A5_Score    0.119456
# 6   A7_Score    0.079008
# 3   A4_Score    0.063024
# 7   A8_Score    0.062193
# 5   A6_Score    0.058929
# 2   A3_Score    0.056256
# 0   A1_Score    0.051508
# 9  A10_Score    0.044479
# 1   A2_Score    0.032530

# %%
X.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score'],
#       dtype='object')

# %%
feature_names = ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
       'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score']
text_representation = tree.export_text(test1, feature_names=feature_names)
#r = tree.export_text(test1, feature_names=X.columns)
#print(r)
print(text_representation)
# Out:
# |--- A9_Score <= 0.50
# |   |--- A6_Score <= 0.50
# |   |   |--- A5_Score <= 0.50
# |   |   |   |--- class: Sem_Autismo
# |   |   |--- A5_Score >  0.50
# |   |   |   |--- A3_Score <= 0.50
# |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |--- A3_Score >  0.50
# |   |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |--- A6_Score >  0.50
# |   |   |--- A7_Score <= 0.50
# |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |--- A5_Score <= 0.50
# |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |--- A5_Score >  0.50
# |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |--- class: Autismo
# |   |   |--- A7_Score >  0.50
# |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |--- A5_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A5_Score >  0.50
# |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |--- class: Autismo
# |--- A9_Score >  0.50
# |   |--- A5_Score <= 0.50
# |   |   |--- A3_Score <= 0.50
# |   |   |   |--- class: Sem_Autismo
# |   |   |--- A3_Score >  0.50
# |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |--- A1_Score <= 0.50
# |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |--- A1_Score >  0.50
# |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |--- class: Autismo
# |   |--- A5_Score >  0.50
# |   |   |--- A1_Score <= 0.50
# |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |--- A6_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A6_Score >  0.50
# |   |   |   |   |   |   |--- A3_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A3_Score >  0.50
# |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |--- class: Autismo
# |   |   |--- A1_Score >  0.50
# |   |   |   |--- A6_Score <= 0.50
# |   |   |   |   |--- A3_Score <= 0.50
# |   |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |--- A3_Score >  0.50
# |   |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |   |--- A4_Score <= 0.50
# |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |--- A4_Score >  0.50
# |   |   |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |--- A6_Score >  0.50
# |   |   |   |   |--- A10_Score <= 0.50
# |   |   |   |   |   |--- A8_Score <= 0.50
# |   |   |   |   |   |   |--- A2_Score <= 0.50
# |   |   |   |   |   |   |   |--- A7_Score <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Sem_Autismo
# |   |   |   |   |   |   |   |--- A7_Score >  0.50
# |   |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |   |--- A2_Score >  0.50
# |   |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |   |--- A8_Score >  0.50
# |   |   |   |   |   |   |--- class: Autismo
# |   |   |   |   |--- A10_Score >  0.50
# |   |   |   |   |   |--- class: Autismo

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

import graphviz
# DOT data
dot_data = tree.export_graphviz(test1, out_file=None, 
                                feature_names=X.columns,  
                                class_names=['Sem_Autismo', 'Autismo'],
                                filled=True)

# Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph

# %%
graph.render("decision_tree_graphivz")
# Out:
# 'decision_tree_graphivz.png'

# %% [markdown]
# ![Árvore de decisão](decision_tree_graphivz.png "Árvore de decisão")

# %% [markdown]
# ## Comparação de desempenho entre modelos

# %%
# Decision Tree
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.4, random_state = 40)
test1 = baseline.fit(x_train,y_train)
results = test1.predict(x_test)
y_pred = results
print("Decision Tree")
print(sklearn.metrics.classification_report(y_test, y_pred))


print("============================================================")

#Random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print("Random forest")
print(sklearn.metrics.classification_report(y_test, y_pred))

print("============================================================")

# SVM
from sklearn.svm import SVC
model = SVC()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("SVM")
print(sklearn.metrics.classification_report(y_test, y_pred))



print("============================================================")

# LogisticRegression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("LogisticRegression")
print(sklearn.metrics.classification_report(y_test, y_pred))


print("============================================================")

# Naive Bayes
from sklearn.naive_bayes  import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print("Naive Bayes")
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
# Decision Tree
#               precision    recall  f1-score   support
#
#      Autismo       0.90      0.89      0.90        83
#  Sem_Autismo       0.95      0.96      0.96       199
#
#     accuracy                           0.94       282
#    macro avg       0.93      0.93      0.93       282
# weighted avg       0.94      0.94      0.94       282
#
# ============================================================
# Random forest
#               precision    recall  f1-score   support
#
#      Autismo       0.94      0.94      0.94        83
#  Sem_Autismo       0.97      0.97      0.97       199
#
#     accuracy                           0.96       282
#    macro avg       0.96      0.96      0.96       282
# weighted avg       0.96      0.96      0.96       282
#
# ============================================================
# SVM
#               precision    recall  f1-score   support
#
#      Autismo       1.00      0.95      0.98        83
#  Sem_Autismo       0.98      1.00      0.99       199
#
#     accuracy                           0.99       282
#    macro avg       0.99      0.98      0.98       282
# weighted avg       0.99      0.99      0.99       282
#
# ============================================================
# LogisticRegression
#               precision    recall  f1-score   support
#
#      Autismo       1.00      1.00      1.00        83
#  Sem_Autismo       1.00      1.00      1.00       199
#
#     accuracy                           1.00       282
#    macro avg       1.00      1.00      1.00       282
# weighted avg       1.00      1.00      1.00       282
#
# ============================================================
# Naive Bayes
#               precision    recall  f1-score   support
#
#      Autismo       0.97      0.84      0.90        83
#  Sem_Autismo       0.94      0.99      0.96       199
#
#     accuracy                           0.95       282
#    macro avg       0.96      0.92      0.93       282
# weighted avg       0.95      0.95      0.95       282

# %% [markdown]
# ## Identificação de feature importance entre a Decision Tree e Random Forest

# %%
# Decision Tree
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.4, random_state = 40)
test1 = baseline.fit(x_train,y_train)
results = test1.predict(x_test)
y_pred = results
print("Decision Tree")

aux = baseline.fit(train_x,train_y)
dic = {i:baseline.feature_importances_[v] for v,i in enumerate(X.columns)}
pd.DataFrame(list(dic.items()), columns=['feature', 'importance']).sort_values(by='importance', ascending=False)
# Out:
# Decision Tree
#      feature  importance
# 8   A9_Score    0.432617
# 4   A5_Score    0.119456
# 6   A7_Score    0.079008
# 3   A4_Score    0.063024
# 7   A8_Score    0.062193
# 5   A6_Score    0.058929
# 2   A3_Score    0.056256
# 0   A1_Score    0.051508
# 9  A10_Score    0.044479
# 1   A2_Score    0.032530

# %%
# LogisticRegression
from sklearn.linear_model import LogisticRegression
print("LogisticRegression")

clf = LogisticRegression(random_state = 0)
clf.fit(x_train, y_train)

feature_importance = abs(clf.coef_[0])
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

dic = {i:feature_importance[v] for v,i in enumerate(X.columns)}
pd.DataFrame(list(dic.items()), columns=['feature', 'importance']).sort_values(by='importance', ascending=False)
# Out:
# LogisticRegression
#      feature  importance
# 8   A9_Score  100.000000
# 3   A4_Score   94.983643
# 4   A5_Score   89.236087
# 0   A1_Score   85.055777
# 9  A10_Score   83.843588
# 5   A6_Score   83.391739
# 2   A3_Score   81.193875
# 7   A8_Score   75.790617
# 6   A7_Score   74.418441
# 1   A2_Score   71.519248
